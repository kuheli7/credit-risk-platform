# %% [markdown]
# # NeoStats Credit Risk Intelligence Platform
# ## Home Credit Default Risk Dataset Exploration & 5 Key Business Insights
#
# This notebook documents comprehensive data quality inspection, feature taxonomy mapping, and five core empirical credit findings.

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path('.').resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.utils.helpers import resolve_data_file

print('Libraries and project paths loaded.')

# %% [markdown]
# ### 1. Data Ingestion & Class Imbalance Audit

# %%
app_path = resolve_data_file('application_train.csv')
df_app = pd.read_csv(app_path, nrows=50000)
default_rate = df_app['TARGET'].mean() * 100
print(f'Total Applications: {len(df_app):,}')
print(f'Default Rate: {default_rate:.2f}% (Class Imbalance ~{(100-default_rate)/default_rate:.1f}:1)')

# %% [markdown]
# ### 2. Five Strategic Business Insights
# 1. **Insight 1:** Default Rate by Contract Type (Cash vs Revolving)
# 2. **Insight 2:** Occupational Vulnerability and High-Risk Job Profiles
# 3. **Insight 3:** Predictive Supremacy of External Bureau Scores (EXT_SOURCE_2/3)
# 4. **Insight 4:** Debt-to-Income Leverage and Non-Linear Default Spikes
# 5. **Insight 5:** Age Cohort Stability and Repayment Track Record

# %%
from notebooks.eda import run_exploratory_data_analysis
run_exploratory_data_analysis()
